# %% [markdown]
# # Detect Abrupt Trends
#
# PyTrendy can identify short abrupt shifts in time series data, with flexibility for padding to identify following periods of persistent effects. This is sometimes referred to as changepoint detection. This notebook will walk you through examples of this, and how you can customise what is considered as an abrupt trend period.

# %% [markdown]
# ![](https://raw.githubusercontent.com/RussellSB/pytrendy/refs/heads/develop/plots/Abrupt.gif)

# %% [markdown]
# ## Installation
#
# Install PyTrendy using pip, and import.

# %%
# %pip install pytrendy -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytrendy as pt

# %% [markdown]
# ## Load Example Data
#
# PyTrendy comes with built-in synthetic datasets for demonstration. Here, we load a time series of 6 months with two abrupt trends.

# %%
# Load a synthetic time series with abrupt trends
df = pt.load_data('series_synthetic')[['date', 'abrupt']]
df.head()
# Out:
#          date     abrupt
# 0  2025-01-01  19.578066
# 1  2025-01-02  19.358378
# 2  2025-01-03  19.228408
# 3  2025-01-04  19.727130
# 4  2025-01-05  20.773716

# %%
# Visualise the data
df.set_index('date').plot(figsize=(20,3), color='black')
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ## Detect Abrupt Trends (Default)

# %%
# Detect and plot trends in the time series
results = pt.detect_trends(df, date_col='date', value_col='abrupt', plot=True)
results.filter_segments(direction='Up/Down')
# Out:
#            direction       start         end trend_class  pct_change  \
# time_index
# 2                 Up  2025-02-28  2025-03-01      abrupt    2.953613
# 4               Down  2025-05-02  2025-05-05      abrupt   -0.931331
#
#             mltp_change  steps  total_change       SNR  change_rank
# time_index
# 2              3.953613      1     59.029519  5.959392            2
# 4              0.068669      3    -73.804419  9.014544            1

# %% [markdown]
# - The uptrend has a total change of 59.02 over 1 day, while the downtrend has a total change of -73.80 over 3 days.
# - As a result, the downtrend has the higher change rank.

# %% [markdown]
# ## Detect Abrupt Trends with Padding

# %% [markdown]
# You can also use padding to extend the detected segments to periods of persistent effects. This can be especially useful for applications such as Interrupted Time Series Analysis or Pre-Post Analysis.
#
# You can enable padding via `method_params` and `abrupt_padding`:

# %%
results = pt.detect_trends(df
                            , date_col='date'
                            , value_col='abrupt'
                            , plot=True
                            , method_params=dict(abrupt_padding=28) # Specify padding in days. By default this is 0 (disabled).
                        )
results.filter_segments(direction='Up/Down')
# Out:
#            direction       start         end trend_class  padded  pct_change  \
# time_index
# 2                 Up  2025-02-28  2025-03-29      abrupt    True    3.002107
# 4               Down  2025-05-02  2025-06-02      abrupt    True   -0.937571
#
#             mltp_change  steps  total_change        SNR  change_rank
# time_index
# 2              4.002107     29     59.998695  20.386664            2
# 4              0.062429     31    -74.298939   8.910108            1

# %% [markdown]
# By default the abrupt padding is 0 days. When modified you can explicitly set it to higher such as 28 days (4 weeks). This has changed the results:
# - Uptrend has a total change of 59.99 over 29 days, and Downtrend has a total change of -74.29 over 31 days.
# - Total change isn't too different from previous results, since after the abrupt shifts, periods are flat. Their point effects randomly vary up and down around 0.

# %% [markdown]
# See what happens when you specify even longer, e.g. 168 days (6 months):

# %%
results = pt.detect_trends(df
                            , date_col='date'
                            , value_col='abrupt'
                            , plot=True
                            , method_params=dict(abrupt_padding=168) # Specify padding of 6 months
                        )
results.filter_segments(direction='Up/Down')
# Out:
#            direction       start         end trend_class  padded  pct_change  \
# time_index
# 2                 Up  2025-02-28  2025-05-01      abrupt    True    2.988656
# 3               Down  2025-05-02  2025-06-30      abrupt    True   -0.944034
#
#             mltp_change  steps  total_change        SNR  change_rank
# time_index
# 2              3.988656     62     59.729870  23.339405            2
# 3              0.055966     59    -74.811069   9.152818            1

# %% [markdown]
# Now the uptrend is padded all the way until a significant change in persistence is detected. As soon as the signal turns down, the up segment ends, even though 6 months was specified. The same applies to the downtrend, which is extended up until the final date in the dataset.

# %% [markdown]
# ## Combining Abrupt and Gradual Trends

# %% [markdown]
# By design, both modes for detecting gradual and abrupt trends are enabled simultaneously. This allows you to detect both types of trends in the same time series.
#
# Under the hood, PyTrendy makes use of Dynamic Time Warping (DTW) to achieve this. It first detects trends at a broad level with rolling window logic, and then classifies each as either abrupt or gradual with DTW. Based on their trend class, it then follows different post-processing logic to "refine" the trend segments.

# %%
# Loading both abrupt and gradual, combining them into the same dataframe

import pandas as pd

df = pt.load_data('series_synthetic')[['date', 'abrupt']]
temp_df = pt.load_data('series_synthetic')[['date', 'gradual']]

start, end = '2025-07-01', '2025-12-28'
temp_df.date = pd.date_range(start=start, end=end, freq='D')

df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')
temp_df = temp_df.set_index('date')

# Append rows by date, then sort
df = pd.concat([df, temp_df.rename(columns={'gradual': 'abrupt'})])
df = df.sort_index()
df = df.reset_index()

df = df.rename(columns={'abrupt': 'abrupt_then_gradual'})
df
# Out:
#           date  abrupt_then_gradual
# 0   2025-01-01            19.578066
# 1   2025-01-02            19.358378
# 2   2025-01-03            19.228408
# 3   2025-01-04            19.727130
# 4   2025-01-05            20.773716
# ..         ...                  ...
# 357 2025-12-24            20.616883
# 358 2025-12-25            20.978084
# 359 2025-12-26            22.449495
# 360 2025-12-27            23.486652
# 361 2025-12-28            22.240260
#
# [362 rows x 2 columns]

# %%
# Visualise the data
df.set_index('date').plot(figsize=(20,3), color='black')
# Out:
# <Axes: xlabel='date'>

# %%
results = pt.detect_trends(df
                            , date_col='date'
                            , value_col='abrupt_then_gradual'
                            , plot=True
                            , method_params=dict(abrupt_padding=28)
                        )
results.filter_segments(direction='Up/Down')
# Out:
#            direction      start        end trend_class padded  pct_change  \
# time_index
# 2                 Up 2025-02-28 2025-03-29      abrupt   True    3.002107
# 4               Down 2025-05-02 2025-06-02      abrupt   True   -0.937571
# 6                 Up 2025-06-26 2025-07-24     gradual    NaN    4.814085
# 7               Down 2025-07-25 2025-08-05     gradual    NaN   -0.554982
# 8                 Up 2025-08-06 2025-09-14     gradual    NaN    2.053528
# 9               Down 2025-09-15 2025-09-29     gradual    NaN   -0.591909
# 10                Up 2025-09-30 2025-11-05     gradual    NaN    3.675005
# 11              Down 2025-11-06 2025-12-15     gradual    NaN   -0.805442
#
#             mltp_change  steps  total_change        SNR  change_rank
# time_index
# 2              4.002107     29     59.998695  20.386664            4
# 4              0.062429     31    -74.298939   8.910108            1
# 6              5.814085     28     22.716340  19.989159            7
# 7              0.445018     11    -13.564214  17.360657            8
# 8              3.053528     39     27.402597  18.645880            5
# 9              0.408091     14    -22.721861  16.762790            6
# 10             4.675005     36     72.611833  21.701162            3
# 11             0.194558     39    -73.253968  21.122099            2

# %% [markdown]
# PyTrendy still correctly identifies the abrupt downtrend with the highest change rank. Following that is the steepest gradual downtrend, then the steepest uptrend.

# %% [markdown]
# Let's say, however, that I'm only interested in comparing the uptrends with each other. With `.filter_segments` you can limit the focus to that.

# %%
results = results.filter_segments(direction='Up', sort_by='change_rank') # order in desc by change rank
results
# Out:
#            direction      start        end trend_class  pct_change  \
# time_index
# 10                Up 2025-09-30 2025-11-05     gradual    3.675005
# 2                 Up 2025-02-28 2025-03-29      abrupt    3.002107
# 8                 Up 2025-08-06 2025-09-14     gradual    2.053528
# 6                 Up 2025-06-26 2025-07-24     gradual    4.814085
#
#             mltp_change  steps  total_change        SNR  change_rank padded
# time_index
# 10             4.675005     36     72.611833  21.701162            3    NaN
# 2              4.002107     29     59.998695  20.386664            4   True
# 8              3.053528     39     27.402597  18.645880            5    NaN
# 6              5.814085     28     22.716340  19.989159            7    NaN

# %% [markdown]
# Since `sort_by='change_rank'` was specified, the results are already ordered from highest to lowest total change. If you want the rank column to reflect that ordering, you can re-compute it to take advantage of the new index.

# %%
results['change_rank'] = results.reset_index().index + 1 # update change rank to only be for uptrends
results
# Out:
#            direction      start        end trend_class  pct_change  \
# time_index
# 10                Up 2025-09-30 2025-11-05     gradual    3.675005
# 2                 Up 2025-02-28 2025-03-29      abrupt    3.002107
# 8                 Up 2025-08-06 2025-09-14     gradual    2.053528
# 6                 Up 2025-06-26 2025-07-24     gradual    4.814085
#
#             mltp_change  steps  total_change        SNR  change_rank padded
# time_index
# 10             4.675005     36     72.611833  21.701162            1    NaN
# 2              4.002107     29     59.998695  20.386664            2   True
# 8              3.053528     39     27.402597  18.645880            3    NaN
# 6              5.814085     28     22.716340  19.989159            4    NaN

# %% [markdown]
# Now we clearly see the gradual uptrend as having the highest change rank, followed by the abrupt uptrend, then the second steepest gradual uptrend.

# %% [markdown]
# Padding is not limited to abrupt trends. [PR #243](https://github.com/RussellSB/pytrendy/pull/243) added `gradual_padding`, which extends gradual Up/Down segments into adjacent flat periods in exactly the same way that `abrupt_padding` extends abrupt segments.
#
# Here we re-run the combined example above, setting both `abrupt_padding` and `gradual_padding` to 120 days:

# %%
results = pt.detect_trends(df
                            , date_col='date'
                            , value_col='abrupt_then_gradual'
                            , plot=True
                            , method_params=dict(abrupt_padding=120, gradual_padding=120) # Set both abrupt and gradual padding to 120 days.
                        )
results.filter_segments(direction='Up/Down')
# Out:
#            direction      start        end trend_class  padded  pct_change  \
# time_index
# 2                 Up 2025-02-28 2025-05-01      abrupt    True    2.988656
# 3               Down 2025-05-02 2025-06-25      abrupt    True   -0.960594
# 4                 Up 2025-06-26 2025-07-24     gradual   False    4.814085
# 5               Down 2025-07-25 2025-08-05     gradual   False   -0.554982
# 6                 Up 2025-08-06 2025-09-14     gradual   False    2.053528
# 7               Down 2025-09-15 2025-09-29     gradual   False   -0.591909
# 8                 Up 2025-09-30 2025-11-05     gradual   False    3.675005
# 9               Down 2025-11-06 2025-12-20     gradual    True   -0.800153
# 10                Up 2025-12-21 2025-12-28     gradual    True    0.057824
#
#             mltp_change  steps  total_change        SNR  change_rank
# time_index
# 2              3.988656     62     59.729870  23.339405            4
# 3              0.039406     54    -76.123387   9.109783            1
# 4              5.814085     28     22.716340  19.989159            7
# 5              0.445018     11    -13.564214  17.360657            8
# 6              3.053528     39     27.402597  18.645880            5
# 7              0.408091     14    -22.721861  16.762790            6
# 8              4.675005     36     72.611833  21.701162            3
# 9              0.199847     44    -72.772968  20.971364            2
# 10             1.057824      7      1.215729  23.497147           10

# %% [markdown]
# Gradual padding behaves in the same way as abrupt padding: a gradual Up/Down segment is extended into the flat period that follows it, up to the next non-flat segment or the end of the dataset. For example, on `series_synthetic`'s gradual column, the default downtrend `2025-01-25 → 2025-02-05` (11 steps) is padded to `2025-02-09` (15 steps), absorbing the flat run; raising `gradual_padding` from 42 to 120 does not extend it further, because the next uptrend begins immediately after.
#
# In the combined series above, padding to 120 extends the abrupt downtrend well beyond the shorter run: from 3 steps unpadded (`2025-05-02 → 2025-05-05`), to 31 steps with `abrupt_padding=28`, to 54 steps here (`2025-05-02 → 2025-06-25`). That is the same 54 steps seen at 90 — raising the padding further does not extend it, because the flat run already ends at the next gradual uptrend.
#
# The final gradual downtrend still extends from 39 steps unpadded (`2025-11-06 → 2025-12-15`) to 44 steps (`2025-11-06 → 2025-12-20`), but not further at 120: the remaining steps turn up and are detected as a short padded uptrend (`2025-12-21 → 2025-12-28`).
#
# Padding is typically more important for abrupt segments, for example in quasi-experimental settings; for gradual trends, whether it helps depends on the data.

# %% [markdown]
# ## Conclusion
#
# PyTrendy provides a flexible toolkit for detecting both abrupt and gradual trends. In this notebook, we demonstrated how to:
#
# - Detect abrupt trends and analyze their magnitude and duration.
# - Apply padding to capture persistent effects after abrupt changes.
# - Combine abrupt and gradual trends into a single analysis.
# - Apply padding to both abrupt and gradual trends via `method_params` (`abrupt_padding` and `gradual_padding`).

# %% [markdown]
# # This H1 header will be the the title.

# %%
# %pip install pytrendy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytrendy in /home/russellsb/.local/lib/python3.10/site-packages (1.1.10)
# Requirement already satisfied: scipy in /home/russellsb/.local/lib/python3.10/site-packages (from pytrendy) (1.15.3)
# Requirement already satisfied: numpy in /home/russellsb/.local/lib/python3.10/site-packages (from pytrendy) (1.26.4)
# Requirement already satisfied: pandas in /home/russellsb/.local/lib/python3.10/site-packages (from pytrendy) (2.3.3)
# Requirement already satisfied: matplotlib in /home/russellsb/.local/lib/python3.10/site-packages (from pytrendy) (3.10.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/russellsb/.local/lib/python3.10/site-packages (from matplotlib->pytrendy) (1.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/russellsb/.local/lib/python3.10/site-packages (from matplotlib->pytrendy) (4.62.1)
# Requirement already satisfied: pyparsing>=3 in /home/russellsb/.local/lib/python3.10/site-packages (from matplotlib->pytrendy) (3.3.2)
# Requirement already satisfied: packaging>=20.0 in /home/russellsb/.local/lib/python3.10/site-packages (from matplotlib->pytrendy) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/russellsb/.local/lib/python3.10/site-packages (from matplotlib->pytrendy) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/russellsb/.local/lib/python3.10/site-packages (from matplotlib->pytrendy) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /home/russellsb/.local/lib/python3.10/site-packages (from matplotlib->pytrendy) (0.12.1)
# Requirement already satisfied: pillow>=8 in /home/russellsb/.local/lib/python3.10/site-packages (from matplotlib->pytrendy) (12.1.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/russellsb/.local/lib/python3.10/site-packages (from pandas->pytrendy) (2025.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->pytrendy) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->pytrendy) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytrendy as pt
df = pt.load_data('series_synthetic')
results = pt.detect_trends(df, date_col='date', value_col='gradual', plot=True)
results.print_summary()
# Out:
# Detected:
# - 3 Uptrends.
# - 3 Downtrends.
# - 3 Flats.
# - 0 Noise.
#
# The best detected trend is Down between dates 2025-05-09 - 2025-06-17
#
# Full Results:
# -------------------------------------------------------------------------------
#             direction       start         end  days  total_change  change_rank  \
# time_index
# 1                 Up  2025-01-02  2025-01-24    22     14.013348          5.0
# 2               Down  2025-01-25  2025-02-05    11    -13.564214          6.0
# 3               Flat  2025-02-06  2025-02-09     3           NaN          NaN
# 4                 Up  2025-02-10  2025-03-14    32     24.632035          3.0
# 5               Flat  2025-03-15  2025-03-17     2           NaN          NaN
# 6               Down  2025-03-18  2025-04-01    14    -22.721861          4.0
# 7                 Up  2025-04-02  2025-05-08    36     72.611833          2.0
# 8               Down  2025-05-09  2025-06-17    39    -73.253968          1.0
# 9               Flat  2025-06-18  2025-06-30    12           NaN          NaN
#
#            trend_class
# time_index
# 1              gradual
# 2              gradual
# 3                  NaN
# 4              gradual
# 5                  NaN
# 6              gradual
# 7              gradual
# 8              gradual
# 9                  NaN
# -------------------------------------------------------------------------------

# %%
results.df_summary
# Out:
#            direction       start         end  days  total_change  change_rank  \
# time_index
# 1                 Up  2025-01-02  2025-01-24    22     14.013348          5.0
# 2               Down  2025-01-25  2025-02-05    11    -13.564214          6.0
# 3               Flat  2025-02-06  2025-02-09     3           NaN          NaN
# 4                 Up  2025-02-10  2025-03-14    32     24.632035          3.0
# 5               Flat  2025-03-15  2025-03-17     2           NaN          NaN
# 6               Down  2025-03-18  2025-04-01    14    -22.721861          4.0
# 7                 Up  2025-04-02  2025-05-08    36     72.611833          2.0
# 8               Down  2025-05-09  2025-06-17    39    -73.253968          1.0
# 9               Flat  2025-06-18  2025-06-30    12           NaN          NaN
#
#            trend_class
# time_index
# 1              gradual
# 2              gradual
# 3                  NaN
# 4              gradual
# 5                  NaN
# 6              gradual
# 7              gradual
# 8              gradual
# 9                  NaN
